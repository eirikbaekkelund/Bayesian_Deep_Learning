# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE".

# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.distributions as dist
import torch.nn as nn

# %matplotlib inline

# %% [markdown]
# # Stochastic gradient Langevin dynamics, and uncertainty quantification
#
# In this first part of the coursework you'll do two things:
#
# * Implement stochastic gradient Langevin dynamics for sampling from a Bayesian neural network
# * Break down the variance to estimate epistemic and aleatoric uncertainty
#
# We're going to run this on the following toy 2D dataset, consisting of **two moons**, each a different class.

# %%
dataset, validation_set = torch.load("two_moons.pt")
X_train, y_train = dataset.tensors
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');
plt.xlim(-3,3)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %% [markdown]
# ## We'll use the following simple feedforward network.

# %%
class TwoMoonsNetwork(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(nn.Linear(2, 100),
                        nn.ReLU(), 
                        nn.Linear(100, 10),
                        nn.ReLU(),
                        nn.Linear(10, 1))
        
    def forward(self, x):
        h = self.net(x)
        return torch.sigmoid(h).squeeze(1)
    
network = TwoMoonsNetwork()

# %% [markdown]
# # TASK 1 (5 points): Define the likelihood and the prior
#
# Let $x_i \in \mathbb{R}^2$ denote an input, $y_i \in \{ 0, 1\}$ a target, and $\theta$ the network parameters.
#
# Let $\hat y_i = f_\theta(x_i)$ denote the output of the network $f_\theta$.
#
# You need to define:
#
# * `log_likelihood`, evaluating a Bernoulli distribution $$\log p(y|x, \theta) = \log \mathrm{Bernoulli}(y | f_\theta(x));$$
# * `log_prior`, evaluating a standard normal distribution $$\log p(\theta) = \log \mathcal{N}(\theta | 0, I).$$
#
# Both of these functions should return a numeric scalar value.
#
# For the prior, you will need to somehow access the parameters of the network! There are several ways of doing this. I suggest looking at the pytorch documentation for either
#
# * iterating through `network.parameters()`, or
# * using helper functions such as `nn.utils.parameters_to_vector`

# %%
def log_likelihood(network, X, y):
    """
    This function computes the log probability `log p(y | x, theta)`
    for a batch of inputs X.
    
    INPUT:
    network : instance of classifier network, extends `nn.Module`
    X       : batch of inputs; torch.FloatTensor, matrix of shape = (batch_size, 2)
    y       : batch of targets: torch.FloatTensor, vector of shape = (batch_size,)
    
    OUTPUT:
    lp      : log probability value of log p(y | x, theta); scalar
    
    """
    assert(network.forward(X).shape[-1] == y.shape[0])
    return dist.Bernoulli(network.forward(X)).log_prob(y).sum(0)

# %%
# grading

# %%
def log_prior(network):
    return dist.Normal(loc=0, scale=1).log_prob(nn.utils.parameters_to_vector(network.parameters())).sum(0)

# %%
# grading

# %%
# grading

# %% [markdown]
# # TASK 2 (3 points): Minibatching
#
# Minibatching is "trickier" when we have a prior on the network parameters.
#
# The function `log_joint_minibatch` should return a mini-batch estimate of the log joint of the full data, i.e. returning an estimator of $$\log p(\theta) + \sum_{i=1}^N \log p(y_i | x_i, \theta)$$ but which is evaluated on only the specified subset of the $N$ data points.

# %%
def log_joint_minibatch(network, X_batch, y_batch, N_training):
    """ Return a minibatch estimate of the full log joint probability 
    
    INPUT:
    network    : instance of classifier network, extends `nn.Module`
    X_batch    : batch of inputs; torch.FloatTensor, matrix of shape = (batch_size, 2)
    y_batch    : batch of targets: torch.FloatTensor, vector of shape = (batch_size,)
    N_training : total number of training data instances in the full training set

    OUTPUT:
    lp : return an estimate of log p(y, theta | X), as computed on the batch; scalar.

    """
    M = X_batch.shape[0]
    return (N_training / M) * log_likelihood(network, X_batch, y_batch) + log_prior(network)

# %%
# grading

# %%
# grading

# %% [markdown]
# ## Self-diagnostic
#
# This is a small-enough dataset that we can compute the log joint probability on the whole dataset:

# %%
with torch.no_grad():
    full_data_lp = log_prior(network) + log_likelihood(network, X_train, y_train)
print("Full data log probability: %0.4f" % full_data_lp.item())
# Out:
# Full data log probability: -1324.7039

# %% [markdown]
# ### In the next cell, we call `log_joint_minibatch`.
#
# If all the code is working correctly, the minibatch estimates should be roughly normally-distributed around the true value!
#
# Changing the batch size should not change the mean of this distribution. Try running the cell below several times.
#
# If the histogram is far away from the true value (the black vertical dashed line), then you probably have a bug.

# %%
dataloader = torch.utils.data.DataLoader(dataset, shuffle=True, batch_size=5)

with torch.no_grad():
    batch_lp_est = [log_joint_minibatch(network, X, y, len(dataset)).item() for X, y in dataloader]
plt.hist(batch_lp_est, bins=10);
yl = plt.ylim()
plt.plot(full_data_lp.item()*np.ones(2), [0, plt.ylim()[1]], 'k--')
plt.ylim(yl);
# torch.stack(batch_lp_est).sum()

# %% [markdown]
# ## Train the model (MAP estimation)
#
# Run the following cell to train your model, to find a MAP estimate.

# %%
dataloader = torch.utils.data.DataLoader(dataset, shuffle=True, batch_size=5)
opt = torch.optim.Adam(network.parameters())

N_epochs = 400
train_lp = []

for epoch in range(N_epochs):
    for X, y in dataloader:
        opt.zero_grad()
        loss = -log_joint_minibatch(network, X, y, len(dataset))
        loss.backward()
        
        opt.step()
    with torch.no_grad():
        train_lp.append((log_likelihood(network, X_train, y_train) + log_prior(network)).item())
plt.plot(train_lp)
plt.xlabel("epoch")
plt.ylabel("$p(y, \\theta | x)$");

# %% [markdown]
# ## Confidence plot
#
# To visualize the result, we'll look at a *confidence plot*.
#
# The *confidence* is the probability assigned to whichever class is predicted.
#
# If the most likely class is "yellow", then it shows $p(y = \text{yellow})$. If the most likely class is red, it shows $p(y = \text{red})$.

# %%
XX, YY = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-2, 2, 100))
with torch.no_grad():
    py = network(torch.FloatTensor(np.stack((XX.ravel(), YY.ravel())).T))
    conf = torch.where(py > 0.5, py, 1-py) ## THIS LINE COMPUTES THE CONFIDENCE
    ZZ = conf.reshape(XX.shape)
CS = plt.contourf(XX, YY, ZZ, cmap='Blues', vmin=0.5, vmax=1.2)
plt.colorbar(ticks=np.linspace(0.5, 1, 6))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k')
plt.title("Confidence plot");

# %% [markdown]
# # Calibration and reliability diagrams
#
# I've implemented a reliability diagram plot and expected calibration error computation here.
#
# Could be interesting to see how the number of bins affects the result…!

# %%
def reliability_diagram(y, y_hat, N_bins=10):
    """
    Plot a reliability diagram
    """
    bins = torch.linspace(0, 1, N_bins+1)
    which_bin = (y_hat[:,None] >= bins[1:]).long().sum(-1).numpy()
    freq = [y[which_bin==k].mean().item() for k in range(N_bins)]
    conf = [y_hat[which_bin==k].mean().item() for k in range(N_bins)]
    plt.bar(bins[1]/2+np.arange(N_bins)/N_bins, freq, width=bins[1]*.9);
    plt.plot(conf, freq, 'o-', color='k')
    plt.plot([0, 1], [0, 1], '--', color='#333');

def expected_calibration_error(y, y_hat, N_bins=10):
    """
    Compute the expected calibration error
    """
    bins = torch.linspace(0, 1, N_bins+1)
    which_bin = (y_hat[:,None] >= bins[1:]).long().sum(-1).numpy()
    counts = []
    acc = []
    conf = []
    for k in range(N_bins):
        count = len(y[which_bin==k])
        if count > 0:
            acc.append(y[which_bin==k].mean().item())
            conf.append(y_hat[which_bin==k].mean().item())
        else:
            acc.append(0.0)
            conf.append(0.0)
        counts.append(count)
    return ((np.abs(np.array(acc) - np.array(conf))*np.array(counts))/len(y)).sum()

# %%
with torch.no_grad():
    y_hat = network(validation_set.tensors[0])

reliability_diagram(y=validation_set.tensors[1], y_hat=y_hat)
print("ECE = %0.4f" % expected_calibration_error(validation_set.tensors[1], y_hat))
plt.title("Reliability diagram");
# Out:
# ECE = 0.0422

# %% [markdown]
# # TASK 3 (6 points): stochastic gradient Langevin dynamics (SGLD)
#
# In this task you can get
#
# * 3 points for implementing the SGLD MCMC update
# * 3 points for implementing Monte Carlo prediction
#
# The `SGLD_step` function below should take a current set of network parameters $\theta$, and update them as
#
# $$\theta' = \theta + \frac{\epsilon^2}{2} \nabla_\theta \log p(\theta, y | X) + \epsilon z$$
#
# where $\epsilon$ is a learning rate, $X, y$ are a current mini-batch, and $z \sim \mathcal{N}(0, I)$ and has the same dimensionality as $\theta$.
#
# For more details see the week 7 lecture slides!
#
# Note that you will actually have to **do the update**. The following function does not return anything! Instead, it updates the parameters of the network, similar to how a `torch.optim` optimizer updates the parameters.

# %%
def SGLD_step(network, X, y, N_training, epsilon):
    """
    Run one step of SGLD given a mini-batch, and update the parameters of the network.
    
    INPUT:
    network    : instance of classifier network, extends `nn.Module`
    X_batch    : batch of inputs; torch.FloatTensor, matrix of shape = (batch_size, 2)
    y_batch    : batch of targets: torch.FloatTensor, vector of shape = (batch_size,)
    N_training : total number of training data instances in the full training set
    epsilon    : step size / learning rate parameters (scalar)
    """
    
    step_size = ( 1/2 ) * ( epsilon**2 )
    
    z_dist = dist.Normal(loc=0, scale=1)

    opt.zero_grad()
    log_prob = log_joint_minibatch(network, X, y, 50)
    log_prob.backward()
    #grads_list = [weights.grad for weights in network.parameters()]
    
    idx = 0
    for weights in network.parameters():
        #grads = grads_list[idx]
        #print(grads)
        idx += 1
        w_copy = weights.clone()
        try:
            sample_shape = (weights.shape[0], weights.shape[1])
        except IndexError:
            sample_shape = (weights.shape[0],)
        
        new_weights = w_copy +  step_size*weights.grad + epsilon*z_dist.sample(sample_shape)
        if idx == 1:
            print("New weights:\n", new_weights[0][0])
            print("Old weights:\n", weights[0][0])
        with torch.no_grad():
            weights.copy_(new_weights)
            weights = new_weights

# %%
# grading

# %%
# grading

# %% [markdown]
# ### Cyclic learning rate
#
# We're going to use a cyclic learning rate schedule for $\epsilon$, like discussed in the lectures. That function is pre-written, below.

# %%
def learning_rate_schedule(N_steps, N_samples, epsilon):
    """
    Pre-compute a learning-rate schedule for SGLD.
    
    INPUT:
    N_steps   : number of SGD updates between each "reset"
    N_samples : number of times we reach the lowest target learning rate
    epsilon   : base learning rate
    
    OUTPUT:
    epsilon_t : vector of length N_steps*N_samples, containing epsilon_t at each iteration t
    """
    return epsilon * (np.cos(np.pi * (np.arange(N_samples*N_steps) % N_steps)/N_steps) + 1)

plt.plot(learning_rate_schedule(N_steps=100, N_samples=10, epsilon=0.5));
plt.xlabel("iteration");
plt.ylabel("epsilon");

# %% [markdown]
# ### Running the sampler
# The following function is also given: it will actually run the SGLD sampler, by calling your `SGLD_step` function above.

# %%
def draw_sgld_samples(network, N_samples, N_steps_per_sample, base_epsilon=0.02):
    """
    Draw samples using SGLD, following a prescribed learning rate schedule
    
    OUTPUT:
    samples : torch.FloatTensor, shape = (N_samples, "# of parameters in network")
    """
    lr_schedule = learning_rate_schedule(N_steps_per_sample, N_samples, base_epsilon)
    samples = []
    step = 0
    while True:
        for X, y in dataloader:
            SGLD_step(network, X, y, len(dataset), epsilon=lr_schedule[step])
            step += 1
            if step % N_steps_per_sample == 0:
                samples.append(nn.utils.parameters_to_vector(network.parameters()).detach())
            if step == len(lr_schedule):
                return torch.stack(samples)

# %%
samples = draw_sgld_samples(network, N_samples=50, N_steps_per_sample=200)
print("Tensor holding samples of theta has shape:", samples.shape)
# Out:
# New weights:
#  tensor(0.0122, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(0.0478, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0476, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(0.0122, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0891, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0476, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1058, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0891, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1022, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1058, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0564, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1022, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0912, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0564, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0911, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0912, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1082, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0911, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1180, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1082, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1207, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1180, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0962, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1207, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1092, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0962, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1412, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1092, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1477, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1412, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1321, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1477, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1585, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1321, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1431, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1585, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2265, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1431, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2332, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2265, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2524, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2332, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2499, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2524, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3014, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2499, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2366, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3014, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2344, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2366, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2448, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2344, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2684, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2448, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2733, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2684, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2944, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2733, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2301, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2944, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1515, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2301, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1356, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1515, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1462, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1356, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0962, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1462, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1066, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0962, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0645, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1066, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1033, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0645, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0756, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1033, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0524, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0756, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0525, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0524, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0284, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0525, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0269, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0284, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0534, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0269, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0689, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0534, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0895, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0689, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0662, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0895, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0890, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0662, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.0799, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0890, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1267, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.0799, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1335, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1267, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1827, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1335, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2165, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1827, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2248, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2165, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2394, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2248, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2229, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2394, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2314, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2229, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2632, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2314, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3310, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2632, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3323, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3310, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2939, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3323, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3017, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2939, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2995, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3017, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3427, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2995, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3168, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3427, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3056, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3168, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3348, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3056, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3470, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3348, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3289, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3470, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3090, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3289, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2992, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3090, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.3154, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2992, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2496, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.3154, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2181, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2496, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2046, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2181, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2254, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2046, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2383, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2254, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2162, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2383, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.1923, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.2162, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2190, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.1923, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.2231, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.
grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.7001, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6982, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.7064, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.7001, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6802, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.7064, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.7068, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6802, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.7042, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.7068, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6548, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.7042, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6576, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6548, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6525, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6576, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6382, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6525, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6456, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6382, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6473, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6456, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6498, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6473, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6521, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6498, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6340, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6521, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6313, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6340, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6199, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6313, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5845, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6199, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5682, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5845, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5684, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5682, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5779, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5684, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5851, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5779, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6006, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5851, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5845, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6006, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6027, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5845, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6075, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6027, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.6250, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6075, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5963, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.6250, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5951, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5963, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5723, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5951, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5678, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5723, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5515, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5678, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5150, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5515, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5251, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5150, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5308, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5251, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5254, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5308, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5071, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5254, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5263, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5071, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5334, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5263, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5474, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5334, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5546, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5474, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5658, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5546, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5609, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5658, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5620, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5609, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5708, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5620, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5800, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5708, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5810, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5800, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5884, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5810, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5865, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5884, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5887, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5865, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5841, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5887, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5900, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5841, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5894, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5900, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5818, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5894, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5854, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5818, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5711, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5854, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5671, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5711, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5598, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5671, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5553, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5598, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5515, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5553, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5459, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5515, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5521, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5459, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5472, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5521, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5522, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5472, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5505, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5522, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5519, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5505, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5530, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5519, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5599, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5530, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5594, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5599, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5564, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5594, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5526, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5564, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5594, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5526, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5561, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5594, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5580, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5561, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5564, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5580, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5575, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5564, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5598, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5575, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5580, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5598, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5594, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5580, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5579, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5594, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5580, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5579, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5580, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5541, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5554, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5541, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5547, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5554, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5557, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5547, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5555, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5557, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5552, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5555, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5552, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5548, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5548, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5550, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# New weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Old weights:
#  tensor(-0.5549, grad_fn=<SelectBackward0>)
# Tensor holding samples of theta has shape: torch.Size([50, 1321])

# %% [markdown]
# ## Making predictions
#
# After running the sampler, you now have a `torch.FloatTensor` which contains many different sampled versions of the network parameters $s = 1,\dots,S$.
#
# To make predictions on an input batch $X$, you will somehow need to "load" in the stored parameters, and run the forward pass using different $\theta^{(s)}$.

# %%
for sample in samples:
    print (samples[1][0], '\n')
# Out:
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)
#
# tensor(-0.3245)

# %%
def predict_from_samples(X, network, samples):
    """
    
    INPUT:
    X       : batch of input points at which to make predictions; shape = (batch_size, 2)
    network : instance of classifier network, extends `nn.Module`
    samples : torch.FloatTensor containing samples of theta; shape = (num_samples, "# of parameters in network")
    
    OUTPUT:
    y_hat_samples : torch.FloatTensor containing samples of y_hat; shape = (num_samples, batch_size)
    """
    pred = None
    for sample in samples:
    for name, w_old in network.state_dict().items():
        
        if pred is None:
            pred = torch.where(network.forward(X) > 0.5, torch.FloatTensor([1]), torch.FloatTensor([0]))
           
        else:
            pred = torch.vstack( ( pred, torch.where( network.forward(X) > 0.5, torch.FloatTensor([1]), torch.FloatTensor([0])) ) )
    return pred
# Out:
#   Cell In [25], line 14
#     for name, w_old in network.state_dict().items():
#     ^
# IndentationError: expected an indented block after 'for' statement on line 13

# %%
# The following should be true if your code is working!
assert predict_from_samples(X_train, network, samples).shape == (samples.shape[0], X_train.shape[0])

# %%
# grading

# %%
# grading

# %% [markdown]
# ## Confidence plot and reliability diagrams for the Bayesian classifier

# %%
XX, YY = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-2, 2, 100))
with torch.no_grad():
    XXYY = torch.FloatTensor(np.stack((XX.ravel(), YY.ravel())).T)
    out = predict_from_samples(XXYY, network, samples)
    py = out.mean(0)
    conf = torch.where(py > 0.5, py, 1-py)
    ZZ = conf.reshape(XX.shape)
CS = plt.contourf(XX, YY, ZZ, cmap='Blues', vmin=0.5, vmax=1.2)
plt.colorbar(ticks=np.linspace(0.5, 1, 6))
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');
plt.title("Confidence plot");

# %%
with torch.no_grad():
    y_hat = predict_from_samples(validation_set.tensors[0], network, samples).mean(0)

reliability_diagram(y=validation_set.tensors[1], y_hat=y_hat)
print("ECE = %0.4f" % expected_calibration_error(validation_set.tensors[1], y_hat))

plt.title("Reliability diagram");

# %% [markdown]
# ## Uncertainty quantification
#
# We can measure the uncertainty in our predictor by looking at the variance of the predictive distribution
#
# $$p(y | \hat y).$$
#
# Here, $\hat y$ is the posterior mean: the average $p(y = 1)$ estimated across all posterior samples.
#
# The total predictive variance of $y$ is the variance of this distribution, i.e.
#
# $$Var [ y | x ] = Var \left [ \int p(y | x, \theta)p(\theta | \mathcal{D}) d\theta \right]$$
#
# One way to estimate epistemic and aleatoric uncertainty is to look at the variance of $\hat y$, i.e. the variance in $f_\theta(x)$ under the posterior over $\theta$. This corresponds to epistemic uncertainty. The difference between these two is then roughly the aleatoric uncertainty.
#
# There are probably better ways to compute (and explain!) this, but hopefully the following plots look clear.

# %%
# Variance of predictive distribution over y
var_of_prediction = dist.Bernoulli(out.mean(0)).variance

# Epistemic uncertainty: Variance across values of y_hat
var_of_mean = out.var(0)

# %% [markdown]
# ### Darker colors are more uncertain:

# %%
plt.title("All uncertainty ($Var[y | x]$)")
plt.contourf(XX, YY, var_of_prediction.reshape(XX.shape), cmap='Blues', vmin=0, vmax=0.3)
plt.colorbar();
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');
# - torch.sigmoid(out).var(0).reshape(XX.shape))

# %%
plt.title("Epistemic uncertainty only")
plt.contourf(XX, YY, var_of_mean.reshape(XX.shape), cmap='Blues', vmin=0, vmax=0.28)
plt.colorbar();
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');

# %%
plt.title("Aleatoric uncertainty only")
plt.contourf(XX, YY, (var_of_prediction - var_of_mean).reshape(XX.shape), cmap='Blues', vmin=0, vmax=0.3)
plt.colorbar();
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='autumn', edgecolor='k');

# %% [markdown]
# # TASK 4 (up to 5 points, free response): Interpretation
#
# Take a look at Figure 1 in the paper https://arxiv.org/pdf/2002.10118.pdf, "Being Bayesian, Even Just a Bit, Fixes Overconfidence in ReLU Networks", Kristiadi et al. 2020.
#
# 1. (4 points) Qualitatively, the uncertainty in figure 1 probably looks quite different from your plots in this notebook. Try to give two different reasons for why the results here might be different.
# 2. (1 point) What is going on with calibration / temperature scaling? Why doesn't the temperature scaling help in Figure 1 in the paper, and why doesn't the ECE improve in this case when we do sampling?

# %% [markdown]
# YOUR ANSWER HERE
